# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,recall_score
from sklearn.ensemble import RandomForestClassifier

# %%
#importing data and splitting it 
df=pd.read_csv("randomforestclas.csv")
x=df[["Temperature","Humidity"]]
y=df["EnergyConsumption"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = RandomForestClassifier(n_estimators=100,random_state=42)
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
acc=accuracy_score(y_test,y_pred)
print("The accuracy of the system is: ",acc)
print("the model predicited this  as:",model.predict([["22","60"]])[0])
# Out:
# The accuracy of the system is:  0.75
# the model predicited this  as: 30
# /Users/jashwanth/Documents/AI_LAB/ML_CODES/myenv/lib/python3.14/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
