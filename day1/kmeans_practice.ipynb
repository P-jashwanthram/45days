# %%
#importing
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
#importing the data
df=pd.read_csv("mall_customers.csv")
df.head()
x=df[["AnnualIncome","SpendingScore"]]
scaled=StandardScaler()
x=scaled.fit_transform(x)

# %%
#training the model with 3 clusters
model=KMeans(n_clusters=3,random_state=42)
model.fit(x)
df["kmeans_label"]=model.labels_
df.head()
print("The clustering result is: ",model.inertia_)
# Out:
# The clustering result is:  17.8313384184191

# %%
#training the model with 5 clusters
model=KMeans(n_clusters=5,random_state=42)
model.fit(x)
df["kmeans_label"]=model.labels_
df.head()
print("The clustering result is: ",model.inertia_)
# Out:
# The clustering result is:  9.37652201662246
