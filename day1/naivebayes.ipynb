# %%
import pandas as pd
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv("email_spam.csv")
x=df["Message"]
y=df["Label"]
df.head()
# Out:
#                             Message Label
# 0     Win free money now click here  spam
# 1   Congratulations you won a prize  spam
# 2    Free entry in contest win cash  spam
# 3   Click here to claim your reward  spam
# 4  You have been selected for prize  spam

# %%
vectorized=CountVectorizer()
x_vectorized=vectorized.fit_transform(x)
x_train,x_test,y_train,y_test=train_test_split(x_vectorized,y,test_size=0.2,random_state=42)

# %%
#train the model
model=MultinomialNB()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
acc=accuracy_score(y_test,y_pred)
msg=["hello how are you"]
x_text=vectorized.transform(msg)
print("MOdel predicited this as: ",model.predict(x_text)[0])
# Out:
# MOdel predicited this as:  ham
